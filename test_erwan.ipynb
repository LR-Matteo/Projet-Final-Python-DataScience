# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.7.5-py3-none-any.whl.metadata (11 kB)
# Collecting niquests>=3.15.2 (from openmeteo-requests)
#   Downloading niquests-3.18.4-py3-none-any.whl.metadata (16 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.26.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from niquests>=3.15.2->openmeteo-requests) (3.4.7)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading urllib3_future-2.19.905-py3-none-any.whl.metadata (19 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading wassima-2.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in /opt/python/lib/python3.13/site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (0.16.0)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading jh2-5.0.11-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading qh3-1.7.1-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting flatbuffers==25.9.23 (from openmeteo-sdk>=1.22.0->openmeteo-requests)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Downloading openmeteo_requests-1.7.5-py3-none-any.whl (7.1 kB)
# Downloading niquests-3.18.4-py3-none-any.whl (208 kB)
# Downloading urllib3_future-2.19.905-py3-none-any.whl (721 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.4/721.4 kB 69.3 MB/s  0:00:00
# Downloading jh2-5.0.11-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (399 kB)
# Downloading qh3-1.7.1-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 60.4 MB/s  0:00:00
# Downloading wassima-2.0.6-py3-none-any.whl (140 kB)
# Downloading openmeteo_sdk-1.26.0-py3-none-any.whl (19 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Installing collected packages: flatbuffers, wassima, qh3, openmeteo-sdk, jh2, urllib3-future, niquests, openmeteo-requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [openmeteo-requests]iquests]uture]
# Successfully installed flatbuffers-25.9.23 jh2-5.0.11 niquests-3.18.4 openmeteo-requests-1.7.5 openmeteo-sdk-1.26.0 qh3-1.7.1 urllib3-future-2.19.905 wassima-2.0.6
# Collecting requests-cache
#   Downloading requests_cache-1.3.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /opt/python/lib/python3.13/site-packages (2.4.4)
# Requirement already satisfied: pandas in /opt/python/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: attrs>=21.2 in /opt/python/lib/python3.13/site-packages (from requests-cache) (26.1.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: platformdirs>=2.5 in /opt/python/lib/python3.13/site-packages (from requests-cache) (4.9.4)
# Requirement already satisfied: requests>=2.22 in /opt/python/lib/python3.13/site-packages (from requests-cache) (2.33.1)
# Collecting url-normalize>=2.0 (from requests-cache)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /opt/python/lib/python3.13/site-packages (from requests-cache) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas) (2026.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in /opt/python/lib/python3.13/site-packages (from cattrs>=22.2->requests-cache) (4.15.0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests>=2.22->requests-cache) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests>=2.22->requests-cache) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/python/lib/python3.13/site-packages (from requests>=2.22->requests-cache) (2026.2.25)
# Downloading requests_cache-1.3.1-py3-none-any.whl (70 kB)
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, retry-requests, requests-cache
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [requests-cache]m [requests-cache]
# Successfully installed cattrs-26.1.0 requests-cache-1.3.1 retry-requests-2.0.0 url-normalize-2.2.1

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 52.52,
	"longitude": 13.41,
	"hourly": "temperature_2m",
	"models": "meteofrance_seamless",
}
responses = openmeteo.weather_api(url, params = params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["temperature_2m"] = hourly_temperature_2m

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)
# Out:
# Coordinates: 52.52000045776367°N 13.40999984741211°E
# Elevation: 38.0 m asl
# Timezone difference to GMT+0: 0s
#
# Hourly data
#                           date  temperature_2m
# 0   2026-04-10 00:00:00+00:00          3.5695
# 1   2026-04-10 01:00:00+00:00          2.8695
# 2   2026-04-10 02:00:00+00:00          2.3195
# 3   2026-04-10 03:00:00+00:00          2.0195
# 4   2026-04-10 04:00:00+00:00          2.0695
# ..                        ...             ...
# 163 2026-04-16 19:00:00+00:00             NaN
# 164 2026-04-16 20:00:00+00:00             NaN
# 165 2026-04-16 21:00:00+00:00             NaN
# 166 2026-04-16 22:00:00+00:00             NaN
# 167 2026-04-16 23:00:00+00:00             NaN
#
# [168 rows x 2 columns]
